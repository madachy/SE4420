# %% [markdown]
# # Homework 1
#
# **Student:** Michael Virbia

# %% [markdown]
# ## Problem 1

# %%
class Problem1:
    def __init__(self):
        self.q_times = [3, 4, 3, 3]
        self.time = [5, 10, 6, 9]
        self.den = 30
        self.num = 0

        for i in range(len(self.q_times)):
            self.num += self.q_times[i] * self.time[i]

        print(f"{self.num/self.den:.3f} minutes")


x = Problem1()
# Out:
# 3.333 minutes

# %% [markdown]
# ## Problem 2, 3, 4
#
# See the excel sheet. The problem asks for it to be solved by hand or non-simulation methods.
